# %%
import pymupdf

def extract_text_from_pdf(file_path):
    text = ""
    with pymupdf.open(file_path) as pdf_document:
        for page_num in range(pdf_document.page_count):
            page = pdf_document.load_page(page_num)
            text += page.get_text()
    return text

# Example usage
file_path = r"C:\Users\PRKUMAR\Downloads\a8325d44eadfcecfb5aff5410f838793.pdf"
text = extract_text_from_pdf(file_path)
print(text)
# Out:
# Mr. Sudhakar Rao S
# 615/a3 615/a3,manjunatha Nilaya 30 4th Cross
# Bangalore North Bbmp Mathikere  1st E Cross Road
# Nethajinagar Nethaji Circle 560054
# Bangalore West Bangalore Karnataka India
# Scan & Pay
# Jio Number
# 918035544149
# Statement Number
# 443004891870
# Activation Date
# 29-AUG-2022
# Due Date
# 10-APR-2024
# Current Plan
# Total Payable
# 706.81
# :
# :
# :
# :
# :
# :
# Account Number
# 410586018603
# :
# Billing Cycle Date
# :
# 01-APR-2024
#  || Email: premkumarc1111@gmail.com
# Registered Mobile Number: +917090624040
# JioFiber Bill Summary
# 399+200(13 OTT) 1M
# Payment Received
# (i) Connectivity Services (Includes Data Services)
# Total (i)
# 582.92
# 582.92
# Current Month Charges
# 582.92
# 582.92
# Previous Balance Due
# 123.90
# Total (ii)
# 123.90
# Payment Received
# Current Month Charges
# 123.90
# 123.90
# (ii) Platform Services (Includes Subscription to OTT
#      Services)
# Previous Balance Due
# Total current charges (i + ii)
# (iii) Advanced Payment Received
# -0.01
# 706.82
# 706.81
# Current Balance (i + ii + iii)
# 706.81
# Total Payable
# Amount (`)
# Particulars
# For Your Information:
# o   You can now download your detailed tax invoices on MyJio / jio.com in the
#      invoice history section.
# o   Current month charges reflect the charges levied in any bill period including
#      taxes as applicable.
# o   All the plan rentals are charged in advance for the no. of days till your next
#      bill cycle, except for first bill generated post activation, where it also includes
#      prorated charges from activation date to your billing cycle date.
# Reach Us : 1800-89-69999 ( from other networks) or Call 199 (from Jio Fixed
#                       Line Number) Write to jiofibercare@jio.com Manage your world of
#                       Jio with MyJio app Visit www.jio.com
# Payment Options
# Set JioAutoPay through My Jio App.
# Download the MyJio App from Play
# Store or App Store.
# Standing Instructions
# (Credit Card)
# EBPP
# Register Jio with your bank for an auto bill
# presentment and payment mandate on
# your bank account or credit card.
# JioPay
# Pay bills using credit/debit card
# /netbanking/ e-wallets/UPI on My Jio App
# or visit www.Jio.com and click on Quick
# Pay Download the app from Play Store or
# App Store
# ACH - (Direct Debit)
# Set ACH mandate on your bank
# account. Visit the nearest Jio Store
# along with a cancelled cheque.
# My Jio & Jio.com
# 399+200(13 OTT) 1M: 1)Unlimited Data @ 30 Mbps 2)Unlimited Voice 3)Subscription to 13 PAID OTT apps 4)Connectivity Rental includes
# provision of all CPE(s)
# Note: This plan is an advance rental plan.
# Your Plan Details :
# Base Monthly Rental
# Voice Call (Local/STD)
# Data
# ISD (minutes)
# ` 599
# Unlimited
# Unlimited Data
# 706.82
# Total Current Charges (A+B)
# A.   Plan Charges (excluding taxes)
# Sr No.
# Description
# Service
# From Date
# To Date
# No of Days
# Amount (`)
# 1
# Monthly Plan Charges
# Connectivity
# 01-APR-2024
# 30-APR-2024
# 30
# 494.00
# 2
# Monthly Plan Charges
# Connectivity
# 14-MAR-2024
# 31-MAR-2024
# 18
# 286.84
# 3
# Monthly Plan Charges
# Connectivity
# 14-MAR-2024
# 31-MAR-2024
# 18
# -286.84
# 4
# Monthly Plan Charges
# Platform
# 01-APR-2024
# 30-APR-2024
# 30
# 105.00
# Total
# 599.00
#
# B.   Taxes
# Sr No.
# Description
# Charges (`)
# CGST (`)
# SGST (`)
# Amount (`)
# 1
# Tax
# 599.00
# 53.91
# 53.91
# 107.82
# Payment History
# 29-FEB
# 31-JAN
# 31-DEC
# ` 631.60
# ` 706.82
# ` 706.82
# Your Payment History
# Bill History
# 29-FEB
# 31-JAN
# 31-DEC
# 30-NOV
# 31-OCT
# 30-SEP
# ` 706.81
# ` 631.59
# ` 706.81
# ` 706.81
# ` 706.81
# ` 706.81
# Page Repeat
